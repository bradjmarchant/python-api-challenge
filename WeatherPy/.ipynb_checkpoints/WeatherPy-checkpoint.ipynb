# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
#      |████████████████████████████████| 557 kB 1.5 MB/s eta 0:00:01
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559701 sha256=52a6ae8784f0f4f75312b27b1bd291a5cd3856d4eaa015a357c05c316a890eea
#   Stored in directory: /Users/bradmarchant/Library/Caches/pip/wheels/72/ae/63/5d03cf6dfe5c0e9328fb73f8b30da1948a06b9cceaf2c68d2d
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pprint
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
cities
# Out:
# ['bambous virieux',
#  'punta arenas',
#  'rikitea',
#  'bethel',
#  'harper',
#  'butaritari',
#  'port hardy',
#  'tenabo',
#  'nandu',
#  'anantapur',
#  'taolanaro',
#  'hobart',
#  'atuona',
#  'cabo san lucas',
#  'illoqqortoormiut',
#  'remedios',
#  'camacha',
#  'ilulissat',
#  'puerto narino',
#  'grahamstown',
#  'thinadhoo',
#  'cape town',
#  'bengkulu',
#  'brae',
#  'cidreira',
#  'busselton',
#  'la ronge',
#  'sinnamary',
#  'georgetown',
#  'jamestown',
#  'pringsewu',
#  'thompson',
#  'sur',
#  'ushuaia',
#  'tonekabon',
#  'torbay',
#  'yelovo',
#  'east london',
#  'catamarca',
#  'conde',
#  'kodiak',
#  'klaksvik',
#  'puerto ayora',
#  'albany',
#  'mataura',
#  'nizhneyansk',
#  'dzhebariki-khaya',
#  'arlit',
#  'samusu',
#  'shizilu',
#  'mersing',
#  'new norfolk',
#  'beringovskiy',
#  'lishan',
#  'tapes',
#  'rio grande',
#  'korla',
#  'pisco',
#  'bombay',
#  'port alfred',
#  'marrakesh',
#  'inyonga',
#  'broome',
#  'flin flon',
#  'araouane',
#  'krasnoarmeysk',
#  'tanabe',
#  'berlevag',
#  'bluff',
#  'avarua',
#  'ribeira grande',
#  'daru',
#  'umm lajj',
#  'dikson',
#  'chuy',
#  'flinders',
#  'geraldton',
#  'tromso',
#  'port elizabeth',
#  'saint-medard-en-jalles',
#  'carutapera',
#  'kruisfontein',
#  'qaanaaq',
#  'kapaa',
#  'dancheng',
#  'mahebourg',
#  'iqaluit',
#  'virginia beach',
#  'tazovskiy',
#  'tiksi',
#  'yerbogachen',
#  'vanimo',
#  'mys shmidta',
#  'faya',
#  'turukhansk',
#  'yar-sale',
#  'mar del plata',
#  'ostrovnoy',
#  'hermanus',
#  'saskylakh',
#  'syracuse',
#  'caceres',
#  'pangnirtung',
#  'najran',
#  'komsomolskiy',
#  'crab hill',
#  'port lincoln',
#  'vaitupu',
#  'dongsheng',
#  'ancud',
#  'manokwari',
#  'kalinagar',
#  'lavrentiya',
#  'douglas',
#  'derzhavinsk',
#  'skagastrond',
#  'saint-philippe',
#  'takoradi',
#  'arraial do cabo',
#  'hovd',
#  'leningradskiy',
#  'hithadhoo',
#  'qasigiannguit',
#  'amderma',
#  'tuatapere',
#  'porto de moz',
#  'altay',
#  'kununurra',
#  'waipawa',
#  'bredasdorp',
#  'karpathos',
#  'sofiyivka',
#  'aklavik',
#  'talara',
#  'jacaleapa',
#  'sambava',
#  'vestbygda',
#  'bat yam',
#  'khatanga',
#  'teguldet',
#  'luderitz',
#  'todos santos',
#  'fort myers beach',
#  'dawei',
#  'severo-kurilsk',
#  'bull savanna',
#  'sobolevo',
#  'bilibino',
#  'rehnan',
#  'upernavik',
#  'portland',
#  'pudozh',
#  'rengali',
#  'general teran',
#  'dunedin',
#  'hilo',
#  'grand river south east',
#  'gat',
#  'dingle',
#  'dalbandin',
#  'tasiilaq',
#  'sakakah',
#  'udachnyy',
#  'serta',
#  'san patricio',
#  'kolno',
#  'elk plain',
#  'cairns',
#  'caravelas',
#  'rawson',
#  'belushya guba',
#  'chokurdakh',
#  'ukiah',
#  'pevek',
#  'puerto madryn',
#  'summerville',
#  'baraboo',
#  'ola',
#  'avera',
#  'ahipara',
#  'sao joao da barra',
#  'puerto carreno',
#  'barawe',
#  'benjamin aceval',
#  'sao filipe',
#  'tapaua',
#  'ushtobe',
#  'erzincan',
#  'syasstroy',
#  'nishihara',
#  'ust-kuyga',
#  'vila velha',
#  'puerto escondido',
#  'provideniya',
#  'viligili',
#  'beshpagir',
#  'vaini',
#  'stromness',
#  'longyearbyen',
#  'rorvik',
#  'waddan',
#  'fare',
#  'ponta do sol',
#  'yeppoon',
#  'destin',
#  'charters towers',
#  'katsuura',
#  'sitka',
#  'nikolskoye',
#  'ginir',
#  'vrangel',
#  'jackson',
#  'salinopolis',
#  'yellowknife',
#  'koslan',
#  'te anau',
#  'saleaula',
#  'salinas',
#  'cockburn harbour',
#  'moba',
#  'adrar',
#  'bowen',
#  'labuhan',
#  'sparks',
#  'khangarh',
#  'codrington',
#  'koumac',
#  'solnechnyy',
#  'lolua',
#  'zlatoustovsk',
#  'bilma',
#  'yulara',
#  'krasnozerskoye',
#  'katha',
#  'hambantota',
#  'nouakchott',
#  'miyako',
#  'san vicente',
#  'brigantine',
#  'nevers',
#  'bacuit',
#  'inhambupe',
#  'eidsvag',
#  'sao miguel do araguaia',
#  'nanortalik',
#  'verkhnevilyuysk',
#  'olafsvik',
#  'karratha',
#  'awjilah',
#  'anar darreh',
#  'attawapiskat',
#  'carnarvon',
#  'storforshei',
#  'lebu',
#  'wawa',
#  'tessalit',
#  'kaitangata',
#  'paungde',
#  'kieta',
#  'kahului',
#  'laguna',
#  'myitkyina',
#  'port-gentil',
#  'marawi',
#  'saint-augustin',
#  'sault sainte marie',
#  'igrim',
#  'paracuru',
#  'pernem',
#  'matadi',
#  'banepa',
#  'norman wells',
#  'kavaratti',
#  'talnakh',
#  'vung tau',
#  'sentyabrskiy',
#  'barrow',
#  'innisfail',
#  'rudbar',
#  'pauini',
#  'castro',
#  'tura',
#  'hobyo',
#  'owando',
#  'fort saint john',
#  'shkotovo-26',
#  'lac du bonnet',
#  'pampa',
#  'san cristobal',
#  'mount gambier',
#  'vakhrushevo',
#  'half moon bay',
#  'meadow lake',
#  'faanui',
#  'margate',
#  'honningsvag',
#  'ambanja',
#  'atar',
#  'tigil',
#  'constitucion',
#  'cherskiy',
#  'manaure',
#  'correntina',
#  'ginda',
#  'baruun-urt',
#  'barentsburg',
#  'souillac',
#  'deputatskiy',
#  'axim',
#  'melfi',
#  'lompoc',
#  'borba',
#  'tibacuy',
#  'nome',
#  'kutum',
#  'nizhniy baskunchak',
#  'utiroa',
#  'olinda',
#  'sabha',
#  'grindavik',
#  'severobaykalsk',
#  'guerrero negro',
#  'zhongxing',
#  'mabaruma',
#  'hazorasp',
#  'safwah',
#  'bur gabo',
#  'katherine',
#  'sioux lookout',
#  'ninghai',
#  'kodinsk',
#  'wuda',
#  'bonfim',
#  'coihaique',
#  'mayo',
#  'fairbanks',
#  'ixtapa',
#  'kushima',
#  'zonguldak',
#  'westport',
#  'kirakira',
#  'simi',
#  'filadelfia',
#  'bourges',
#  'palmer',
#  'asau',
#  'trinidad',
#  'labytnangi',
#  'sokoni',
#  'kisangani',
#  'hasaki',
#  'andenes',
#  'yarada',
#  'vostok',
#  'paamiut',
#  'union',
#  'okato',
#  'mont-dore',
#  'tumannyy',
#  'fort nelson',
#  'votkinsk',
#  'khuzdar',
#  'banda aceh',
#  'marzuq',
#  'plettenberg bay',
#  'qeshm',
#  'along',
#  'umtata',
#  'atikokan',
#  'camana',
#  'rocha',
#  'bubaque',
#  'shumskiy',
#  'cururupu',
#  'gazojak',
#  'imbituba',
#  'namatanai',
#  'tabas',
#  'kongsberg',
#  'airai',
#  'taoudenni',
#  'kibre mengist',
#  'brufut',
#  'college',
#  'mapiripan',
#  'veraval',
#  'kachikau',
#  'sorvag',
#  'craidorolt',
#  'mackay',
#  'umzimvubu',
#  'chaa-khol',
#  'saint-francois',
#  'shingu',
#  'muzhi',
#  'broken hill',
#  'mount isa',
#  'narsaq',
#  'amargosa',
#  'gorontalo',
#  'dillon',
#  'miraflores',
#  'richards bay',
#  'kristiinankaupunki',
#  'duz',
#  'price',
#  'general pico',
#  'port augusta',
#  'canmore',
#  'moses lake',
#  'mago',
#  'rumoi',
#  'ulaanbaatar',
#  'makakilo city',
#  'tahoua',
#  'lazurne',
#  'oberwart',
#  'kavieng',
#  'quatre cocos',
#  'isangel',
#  'nexo',
#  'henties bay',
#  'wanning',
#  'sao gabriel da cachoeira',
#  'dzhusaly',
#  'kamaishi',
#  'muroto',
#  'inuvik',
#  'victoria',
#  'davila',
#  'lingao',
#  'wageningen',
#  'novyy oskol',
#  'erenhot',
#  'payson',
#  'chikoy',
#  'nanhai',
#  'kalmar',
#  'araure',
#  'baghmara',
#  'naze',
#  'gainesville',
#  'abhar',
#  'sabang',
#  'artigas',
#  'kendari',
#  'ragonvalia',
#  'srednekolymsk',
#  'freetown',
#  'san rafael del sur',
#  'esperance',
#  'gomel',
#  'leshukonskoye',
#  'aden',
#  'lucapa',
#  'tadine',
#  'chara',
#  'pasighat',
#  'egvekinot',
#  'hervey bay',
#  'kaliningrad',
#  'sumbawa',
#  'padang',
#  'belmonte',
#  'sao sebastiao',
#  'tashtagol',
#  'halalo',
#  'mecca',
#  'roma',
#  'phan thiet',
#  'aksarka',
#  'xalpatlahuac',
#  'svetlogorsk',
#  'gazli',
#  'tuktoyaktuk',
#  'atasu',
#  'salalah',
#  'burnie',
#  'hofu',
#  'bairiki',
#  'sorland',
#  'saldanha',
#  'nador',
#  'hofn',
#  'tabiauea',
#  'acapulco',
#  'ankazoabo',
#  'kuytun',
#  'antalya',
#  'bathsheba',
#  'allanmyo',
#  'san policarpo',
#  'killybegs',
#  'peace river',
#  'chicama',
#  'lata',
#  'aljezur',
#  'bandarbeyla',
#  'kuruman',
#  'ulagan',
#  'coahuayana',
#  'sisimiut',
#  'pangkalanbuun',
#  'ahuimanu',
#  'moyobamba',
#  'steamboat springs',
#  'beloha',
#  'pathardi',
#  'morehead',
#  'namibe',
#  'poya',
#  'herat',
#  'hihifo',
#  'ornskoldsvik',
#  'araguaina',
#  'vila franca do campo',
#  'biltine',
#  'la paz',
#  'vardo',
#  'porto novo',
#  'desbiens',
#  'kulhudhuffushi',
#  'anadyr',
#  'luganville',
#  'alofi',
#  'zholymbet',
#  'aksu',
#  'luwuk',
#  'fortuna',
#  'gannan',
#  'khonuu',
#  'cockburn town',
#  'abu kamal',
#  'ulladulla',
#  'bara',
#  'lockhart',
#  'louisbourg',
#  'fuyu',
#  'lonevag',
#  'zabol',
#  'eyl',
#  'solsvik',
#  'limbang',
#  'tignere',
#  'shizunai',
#  'yunjinghong',
#  'grand gaube',
#  'huarmey',
#  'yingcheng',
#  'cayenne',
#  'oyama',
#  'ambilobe',
#  'seoul',
#  'ternate',
#  'warqla',
#  'novikovo',
#  'humaita',
#  'nosy varika',
#  'tual',
#  'clyde river',
#  'nola',
#  'vorozhba',
#  'aksehir',
#  'maraa',
#  'dwarka',
#  'mindelo',
#  'ambon',
#  'nouadhibou',
#  'tsihombe',
#  'front royal',
#  'loma bonita',
#  'samarai',
#  'seguela',
#  'mullaitivu',
#  'pakwach',
#  'high level',
#  'lircay',
#  'honiara',
#  'cananeia',
#  'mount abu',
#  'indianola',
#  'nsawam',
#  'soyo',
#  'bereda',
#  'ranong',
#  'rokytne',
#  'kloulklubed',
#  'nizhnyaya tavda',
#  'king city',
#  'churapcha',
#  'timra',
#  'angoram',
#  'ngukurr',
#  'usinsk',
#  'collie',
#  'port moresby',
#  'konstantinovka',
#  'cap malheureux',
#  'buchanan',
#  'mocambique',
#  'shemonaikha',
#  'barcelos',
#  'havoysund',
#  'presidencia roque saenz pena',
#  'miyazu',
#  'palabuhanratu',
#  'biak',
#  'djibo',
#  'port macquarie',
#  'novaya igirma',
#  'never',
#  'koshurnikovo',
#  'nichinan',
#  'chumikan',
#  'atbasar',
#  'tabou',
#  'matagami',
#  'ati',
#  'jaciara',
#  'pozo colorado',
#  'tecoanapa']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="
key = f"&appid={weather_api_key}&units=imperial"

# %%
# set up list to hold response info
temp = []
lat = []
lon = []
temp_max = []
humid = []
cloud = []
wind = []
country = []
date = []
name = []
# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(url+ city + key).json()
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        name.append(response['name'])
        num=cities.index(city)+1
        result=f"Processing Record {num} of Set 1 |{city}"
        print(result)
    except KeyError:
        print('City not found. Skipping...')
# Out:
# Processing Record 1 of Set 1 |bambous virieux
# Processing Record 2 of Set 1 |punta arenas
# Processing Record 3 of Set 1 |rikitea
# Processing Record 4 of Set 1 |bethel
# Processing Record 5 of Set 1 |harper
# Processing Record 6 of Set 1 |butaritari
# Processing Record 7 of Set 1 |port hardy
# Processing Record 8 of Set 1 |tenabo
# Processing Record 9 of Set 1 |nandu
# Processing Record 10 of Set 1 |anantapur
# City not found. Skipping...
# Processing Record 12 of Set 1 |hobart
# Processing Record 13 of Set 1 |atuona
# Processing Record 14 of Set 1 |cabo san lucas
# City not found. Skipping...
# Processing Record 16 of Set 1 |remedios
# Processing Record 17 of Set 1 |camacha
# Processing Record 18 of Set 1 |ilulissat
# Processing Record 19 of Set 1 |puerto narino
# Processing Record 20 of Set 1 |grahamstown
# Processing Record 21 of Set 1 |thinadhoo
# Processing Record 22 of Set 1 |cape town
# Processing Record 23 of Set 1 |bengkulu
# Processing Record 24 of Set 1 |brae
# Processing Record 25 of Set 1 |cidreira
# Processing Record 26 of Set 1 |busselton
# Processing Record 27 of Set 1 |la ronge
# Processing Record 28 of Set 1 |sinnamary
# Processing Record 29 of Set 1 |georgetown
# Processing Record 30 of Set 1 |jamestown
# Processing Record 31 of Set 1 |pringsewu
# Processing Record 32 of Set 1 |thompson
# Processing Record 33 of Set 1 |sur
# Processing Record 34 of Set 1 |ushuaia
# Processing Record 35 of Set 1 |tonekabon
# Processing Record 36 of Set 1 |torbay
# Processing Record 37 of Set 1 |yelovo
# Processing Record 38 of Set 1 |east london
# Processing Record 39 of Set 1 |catamarca
# Processing Record 40 of Set 1 |conde
# Processing Record 41 of Set 1 |kodiak
# Processing Record 42 of Set 1 |klaksvik
# Processing Record 43 of Set 1 |puerto ayora
# Processing Record 44 of Set 1 |albany
# Processing Record 45 of Set 1 |mataura
# City not found. Skipping...
# Processing Record 47 of Set 1 |dzhebariki-khaya
# Processing Record 48 of Set 1 |arlit
# City not found. Skipping...
# Processing Record 50 of Set 1 |shizilu
# Processing Record 51 of Set 1 |mersing
# Processing Record 52 of Set 1 |new norfolk
# Processing Record 53 of Set 1 |beringovskiy
# Processing Record 54 of Set 1 |lishan
# Processing Record 55 of Set 1 |tapes
# Processing Record 56 of Set 1 |rio grande
# Processing Record 57 of Set 1 |korla
# Processing Record 58 of Set 1 |pisco
# Processing Record 59 of Set 1 |bombay
# Processing Record 60 of Set 1 |port alfred
# Processing Record 61 of Set 1 |marrakesh
# Processing Record 62 of Set 1 |inyonga
# Processing Record 63 of Set 1 |broome
# Processing Record 64 of Set 1 |flin flon
# Processing Record 65 of Set 1 |araouane
# Processing Record 66 of Set 1 |krasnoarmeysk
# Processing Record 67 of Set 1 |tanabe
# Processing Record 68 of Set 1 |berlevag
# Processing Record 69 of Set 1 |bluff
# Processing Record 70 of Set 1 |avarua
# Processing Record 71 of Set 1 |ribeira grande
# Processing Record 72 of Set 1 |daru
# Processing Record 73 of Set 1 |umm lajj
# Processing Record 74 of Set 1 |dikson
# Processing Record 75 of Set 1 |chuy
# Processing Record 76 of Set 1 |flinders
# Processing Record 77 of Set 1 |geraldton
# Processing Record 78 of Set 1 |tromso
# Processing Record 79 of Set 1 |port elizabeth
# Processing Record 80 of Set 1 |saint-medard-en-jalles
# Processing Record 81 of Set 1 |carutapera
# Processing Record 82 of Set 1 |kruisfontein
# Processing Record 83 of Set 1 |qaanaaq
# Processing Record 84 of Set 1 |kapaa
# Processing Record 85 of Set 1 |dancheng
# Processing Record 86 of Set 1 |mahebourg
# Processing Record 87 of Set 1 |iqaluit
# Processing Record 88 of Set 1 |virginia beach
# Processing Record 89 of Set 1 |tazovskiy
# Processing Record 90 of Set 1 |tiksi
# Processing Record 91 of Set 1 |yerbogachen
# Processing Record 92 of Set 1 |vanimo
# City not found. Skipping...
# Processing Record 94 of Set 1 |faya
# Processing Record 95 of Set 1 |turukhansk
# Processing Record 96 of Set 1 |yar-sale
# Processing Record 97 of Set 1 |mar del plata
# Processing Record 98 of Set 1 |ostrovnoy
# Processing Record 99 of Set 1 |hermanus
# Processing Record 100 of Set 1 |saskylakh
# Processing Record 101 of Set 1 |syracuse
# Processing Record 102 of Set 1 |caceres
# Processing Record 103 of Set 1 |pangnirtung
# Processing Record 104 of Set 1 |najran
# Processing Record 105 of Set 1 |komsomolskiy
# City not found. Skipping...
# Processing Record 107 of Set 1 |port lincoln
# City not found. Skipping...
# Processing Record 109 of Set 1 |dongsheng
# Processing Record 110 of Set 1 |ancud
# Processing Record 111 of Set 1 |manokwari
# Processing Record 112 of Set 1 |kalinagar
# Processing Record 113 of Set 1 |lavrentiya
# Processing Record 114 of Set 1 |douglas
# Processing Record 115 of Set 1 |derzhavinsk
# City not found. Skipping...
# Processing Record 117 of Set 1 |saint-philippe
# Processing Record 118 of Set 1 |takoradi
# Processing Record 119 of Set 1 |arraial do cabo
# Processing Record 120 of Set 1 |hovd
# Processing Record 121 of Set 1 |leningradskiy
# Processing Record 122 of Set 1 |hithadhoo
# Processing Record 123 of Set 1 |qasigiannguit
# City not found. Skipping...
# Processing Record 125 of Set 1 |tuatapere
# Processing Record 126 of Set 1 |porto de moz
# Processing Record 127 of Set 1 |altay
# Processing Record 128 of Set 1 |kununurra
# Processing Record 129 of Set 1 |waipawa
# Processing Record 130 of Set 1 |bredasdorp
# Processing Record 131 of Set 1 |karpathos
# Processing Record 132 of Set 1 |sofiyivka
# Processing Record 133 of Set 1 |aklavik
# Processing Record 134 of Set 1 |talara
# Processing Record 135 of Set 1 |jacaleapa
# Processing Record 136 of Set 1 |sambava
# City not found. Skipping...
# Processing Record 138 of Set 1 |bat yam
# Processing Record 139 of Set 1 |khatanga
# Processing Record 140 of Set 1 |teguldet
# Processing Record 141 of Set 1 |luderitz
# Processing Record 142 of Set 1 |todos santos
# Processing Record 143 of Set 1 |fort myers beach
# Processing Record 144 of Set 1 |dawei
# Processing Record 145 of Set 1 |severo-kurilsk
# Processing Record 146 of Set 1 |bull savanna
# Processing Record 147 of Set 1 |sobolevo
# Processing Record 148 of Set 1 |bilibino
# Processing Record 149 of Set 1 |rehnan
# Processing Record 150 of Set 1 |upernavik
# Processing Record 151 of Set 1 |portland
# Processing Record 152 of Set 1 |pudozh
# Processing Record 153 of Set 1 |rengali
# Processing Record 154 of Set 1 |general teran
# Processing Record 155 of Set 1 |dunedin
# Processing Record 156 of Set 1 |hilo
# City not found. Skipping...
# Processing Record 158 of Set 1 |gat
# Processing Record 159 of Set 1 |dingle
# Processing Record 160 of Set 1 |dalbandin
# Processing Record 161 of Set 1 |tasiilaq
# Processing Record 162 of Set 1 |sakakah
# Processing Record 163 of Set 1 |udachnyy
# Processing Record 164 of Set 1 |serta
# Processing Record 165 of Set 1 |san patricio
# Processing Record 166 of Set 1 |kolno
# Processing Record 167 of Set 1 |elk plain
# Processing Record 168 of Set 1 |cairns
# Processing Record 169 of Set 1 |caravelas
# Processing Record 170 of Set 1 |rawson
# City not found. Skipping...
# Processing Record 172 of Set 1 |chokurdakh
# Processing Record 173 of Set 1 |ukiah
# Processing Record 174 of Set 1 |pevek
# Processing Record 175 of Set 1 |puerto madryn
# Processing Record 176 of Set 1 |summerville
# Processing Record 177 of Set 1 |baraboo
# Processing Record 178 of Set 1 |ola
# Processing Record 179 of Set 1 |avera
# Processing Record 180 of Set 1 |ahipara
# Processing Record 181 of Set 1 |sao joao da barra
# Processing Record 182 of Set 1 |puerto carreno
# City not found. Skipping...
# Processing Record 184 of Set 1 |benjamin aceval
# Processing Record 185 of Set 1 |sao filipe
# City not found. Skipping...
# Processing Record 187 of Set 1 |ushtobe
# Processing Record 188 of Set 1 |erzincan
# Processing Record 189 of Set 1 |syasstroy
# Processing Record 190 of Set 1 |nishihara
# Processing Record 191 of Set 1 |ust-kuyga
# Processing Record 192 of Set 1 |vila velha
# Processing Record 193 of Set 1 |puerto escondido
# Processing Record 194 of Set 1 |provideniya
# City not found. Skipping...
# Processing Record 196 of Set 1 |beshpagir
# Processing Record 197 of Set 1 |vaini
# Processing Record 198 of Set 1 |stromness
# Processing Record 199 of Set 1 |longyearbyen
# Processing Record 200 of Set 1 |rorvik
# Processing Record 201 of Set 1 |waddan
# Processing Record 202 of Set 1 |fare
# Processing Record 203 of Set 1 |ponta do sol
# Processing Record 204 of Set 1 |yeppoon
# Processing Record 205 of Set 1 |destin
# Processing Record 206 of Set 1 |charters towers
# Processing Record 207 of Set 1 |katsuura
# Processing Record 208 of Set 1 |sitka
# Processing Record 209 of Set 1 |nikolskoye
# Processing Record 210 of Set 1 |ginir
# Processing Record 211 of Set 1 |vrangel
# Processing Record 212 of Set 1 |jackson
# Processing Record 213 of Set 1 |salinopolis
# Processing Record 214 of Set 1 |yellowknife
# Processing Record 215 of Set 1 |koslan
# Processing Record 216 of Set 1 |te anau
# City not found. Skipping...
# Processing Record 218 of Set 1 |salinas
# City not found. Skipping...
# Processing Record 220 of Set 1 |moba
# Processing Record 221 of Set 1 |adrar
# Processing Record 222 of Set 1 |bowen
# Processing Record 223 of Set 1 |labuhan
# Processing Record 224 of Set 1 |sparks
# Processing Record 225 of Set 1 |khangarh
# Processing Record 226 of Set 1 |codrington
# Processing Record 227 of Set 1 |koumac
# Processing Record 228 of Set 1 |solnechnyy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 231 of Set 1 |bilma
# Processing Record 232 of Set 1 |yulara
# Processing Record 233 of Set 1 |krasnozerskoye
# City not found. Skipping...
# Processing Record 235 of Set 1 |hambantota
# Processing Record 236 of Set 1 |nouakchott
# Processing Record 237 of Set 1 |miyako
# Processing Record 238 of Set 1 |san vicente
# Processing Record 239 of Set 1 |brigantine
# Processing Record 240 of Set 1 |nevers
# City not found. Skipping...
# Processing Record 242 of Set 1 |inhambupe
# Processing Record 243 of Set 1 |eidsvag
# Processing Record 244 of Set 1 |sao miguel do araguaia
# Processing Record 245 of Set 1 |nanortalik
# Processing Record 246 of Set 1 |verkhnevilyuysk
# Processing Record 247 of Set 1 |olafsvik
# Processing Record 248 of Set 1 |karratha
# Processing Record 249 of Set 1 |awjilah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 252 of Set 1 |carnarvon
# Processing Record 253 of Set 1 |storforshei
# Processing Record 254 of Set 1 |lebu
# Processing Record 255 of Set 1 |wawa
# Processing Record 256 of Set 1 |tessalit
# Processing Record 257 of Set 1 |kaitangata
# Processing Record 258 of Set 1 |paungde
# Processing Record 259 of Set 1 |kieta
# Processing Record 260 of Set 1 |kahului
# Processing Record 261 of Set 1 |laguna
# Processing Record 262 of Set 1 |myitkyina
# Processing Record 263 of Set 1 |port-gentil
# Processing Record 264 of Set 1 |marawi
# Processing Record 265 of Set 1 |saint-augustin
# Processing Record 266 of Set 1 |sault sainte marie
# Processing Record 267 of Set 1 |igrim
# Processing Record 268 of Set 1 |paracuru
# Processing Record 269 of Set 1 |pernem
# Processing Record 270 of Set 1 |matadi
# Processing Record 271 of Set 1 |banepa
# Processing Record 272 of Set 1 |norman wells
# Processing Record 273 of Set 1 |kavaratti
# Processing Record 274 of Set 1 |talnakh
# Processing Record 275 of Set 1 |vung tau
# City not found. Skipping...
# Processing Record 277 of Set 1 |barrow
# Processing Record 278 of Set 1 |innisfail
# Processing Record 279 of Set 1 |rudbar
# Processing Record 280 of Set 1 |pauini
# Processing Record 281 of Set 1 |castro
# Processing Record 282 of Set 1 |tura
# Processing Record 283 of Set 1 |hobyo
# Processing Record 284 of Set 1 |owando
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 287 of Set 1 |lac du bonnet
# Processing Record 288 of Set 1 |pampa
# Processing Record 289 of Set 1 |san cristobal
# Processing Record 290 of Set 1 |mount gambier
# Processing Record 291 of Set 1 |vakhrushevo
# Processing Record 292 of Set 1 |half moon bay
# Processing Record 293 of Set 1 |meadow lake
# Processing Record 294 of Set 1 |faanui
# Processing Record 295 of Set 1 |margate
# Processing Record 296 of Set 1 |honningsvag
# Processing Record 297 of Set 1 |ambanja
# Processing Record 298 of Set 1 |atar
# Processing Record 299 of Set 1 |tigil
# Processing Record 300 of Set 1 |constitucion
# Processing Record 301 of Set 1 |cherskiy
# Processing Record 302 of Set 1 |manaure
# Processing Record 303 of Set 1 |correntina
# Processing Record 304 of Set 1 |ginda
# Processing Record 305 of Set 1 |baruun-urt
# City not found. Skipping...
# Processing Record 307 of Set 1 |souillac
# Processing Record 308 of Set 1 |deputatskiy
# Processing Record 309 of Set 1 |axim
# Processing Record 310 of Set 1 |melfi
# Processing Record 311 of Set 1 |lompoc
# Processing Record 312 of Set 1 |borba
# Processing Record 313 of Set 1 |tibacuy
# Processing Record 314 of Set 1 |nome
# Processing Record 315 of Set 1 |kutum
# Processing Record 316 of Set 1 |nizhniy baskunchak
# City not found. Skipping...
# Processing Record 318 of Set 1 |olinda
# Processing Record 319 of Set 1 |sabha
# Processing Record 320 of Set 1 |grindavik
# Processing Record 321 of Set 1 |severobaykalsk
# Processing Record 322 of Set 1 |guerrero negro
# Processing Record 323 of Set 1 |zhongxing
# Processing Record 324 of Set 1 |mabaruma
# Processing Record 325 of Set 1 |hazorasp
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 328 of Set 1 |katherine
# Processing Record 329 of Set 1 |sioux lookout
# Processing Record 330 of Set 1 |ninghai
# Processing Record 331 of Set 1 |kodinsk
# Processing Record 332 of Set 1 |wuda
# Processing Record 333 of Set 1 |bonfim
# Processing Record 334 of Set 1 |coihaique
# Processing Record 335 of Set 1 |mayo
# Processing Record 336 of Set 1 |fairbanks
# Processing Record 337 of Set 1 |ixtapa
# Processing Record 338 of Set 1 |kushima
# Processing Record 339 of Set 1 |zonguldak
# Processing Record 340 of Set 1 |westport
# Processing Record 341 of Set 1 |kirakira
# Processing Record 342 of Set 1 |simi
# Processing Record 343 of Set 1 |filadelfia
# Processing Record 344 of Set 1 |bourges
# Processing Record 345 of Set 1 |palmer
# Processing Record 346 of Set 1 |asau
# Processing Record 347 of Set 1 |trinidad
# Processing Record 348 of Set 1 |labytnangi
# Processing Record 349 of Set 1 |sokoni
# Processing Record 350 of Set 1 |kisangani
# Processing Record 351 of Set 1 |hasaki
# Processing Record 352 of Set 1 |andenes
# Processing Record 353 of Set 1 |yarada
# Processing Record 354 of Set 1 |vostok
# Processing Record 355 of Set 1 |paamiut
# Processing Record 356 of Set 1 |union
# Processing Record 357 of Set 1 |okato
# Processing Record 358 of Set 1 |mont-dore
# City not found. Skipping...
# Processing Record 360 of Set 1 |fort nelson
# Processing Record 361 of Set 1 |votkinsk
# Processing Record 362 of Set 1 |khuzdar
# Processing Record 363 of Set 1 |banda aceh
# Processing Record 364 of Set 1 |marzuq
# Processing Record 365 of Set 1 |plettenberg bay
# Processing Record 366 of Set 1 |qeshm
# Processing Record 367 of Set 1 |along
# Processing Record 368 of Set 1 |umtata
# Processing Record 369 of Set 1 |atikokan
# Processing Record 370 of Set 1 |camana
# Processing Record 371 of Set 1 |rocha
# Processing Record 372 of Set 1 |bubaque
# Processing Record 373 of Set 1 |shumskiy
# Processing Record 374 of Set 1 |cururupu
# Processing Record 375 of Set 1 |gazojak
# Processing Record 376 of Set 1 |imbituba
# Processing Record 377 of Set 1 |namatanai
# Processing Record 378 of Set 1 |tabas
# Processing Record 379 of Set 1 |kongsberg
# Processing Record 380 of Set 1 |airai
# Processing Record 381 of Set 1 |taoudenni
# Processing Record 382 of Set 1 |kibre mengist
# Processing Record 383 of Set 1 |brufut
# Processing Record 384 of Set 1 |college
# Processing Record 385 of Set 1 |mapiripan
# Processing Record 386 of Set 1 |veraval
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 389 of Set 1 |craidorolt
# Processing Record 390 of Set 1 |mackay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 393 of Set 1 |saint-francois
# Processing Record 394 of Set 1 |shingu
# Processing Record 395 of Set 1 |muzhi
# Processing Record 396 of Set 1 |broken hill
# Processing Record 397 of Set 1 |mount isa
# Processing Record 398 of Set 1 |narsaq
# Processing Record 399 of Set 1 |amargosa
# Processing Record 400 of Set 1 |gorontalo
# Processing Record 401 of Set 1 |dillon
# Processing Record 402 of Set 1 |miraflores
# Processing Record 403 of Set 1 |richards bay
# Processing Record 404 of Set 1 |kristiinankaupunki
# City not found. Skipping...
# Processing Record 406 of Set 1 |price
# Processing Record 407 of Set 1 |general pico
# Processing Record 408 of Set 1 |port augusta
# Processing Record 409 of Set 1 |canmore
# Processing Record 410 of Set 1 |moses lake
# Processing Record 411 of Set 1 |mago
# Processing Record 412 of Set 1 |rumoi
# Processing Record 413 of Set 1 |ulaanbaatar
# Processing Record 414 of Set 1 |makakilo city
# Processing Record 415 of Set 1 |tahoua
# Processing Record 416 of Set 1 |lazurne
# Processing Record 417 of Set 1 |oberwart
# Processing Record 418 of Set 1 |kavieng
# Processing Record 419 of Set 1 |quatre cocos
# Processing Record 420 of Set 1 |isangel
# Processing Record 421 of Set 1 |nexo
# Processing Record 422 of Set 1 |henties bay
# Processing Record 423 of Set 1 |wanning
# Processing Record 424 of Set 1 |sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 426 of Set 1 |kamaishi
# Processing Record 427 of Set 1 |muroto
# Processing Record 428 of Set 1 |inuvik
# Processing Record 429 of Set 1 |victoria
# Processing Record 430 of Set 1 |davila
# Processing Record 431 of Set 1 |lingao
# Processing Record 432 of Set 1 |wageningen
# Processing Record 433 of Set 1 |novyy oskol
# Processing Record 434 of Set 1 |erenhot
# Processing Record 435 of Set 1 |payson
# City not found. Skipping...
# Processing Record 437 of Set 1 |nanhai
# Processing Record 438 of Set 1 |kalmar
# Processing Record 439 of Set 1 |araure
# Processing Record 440 of Set 1 |baghmara
# Processing Record 441 of Set 1 |naze
# Processing Record 442 of Set 1 |gainesville
# Processing Record 443 of Set 1 |abhar
# Processing Record 444 of Set 1 |sabang
# Processing Record 445 of Set 1 |artigas
# Processing Record 446 of Set 1 |kendari
# Processing Record 447 of Set 1 |ragonvalia
# Processing Record 448 of Set 1 |srednekolymsk
# Processing Record 449 of Set 1 |freetown
# Processing Record 450 of Set 1 |san rafael del sur
# Processing Record 451 of Set 1 |esperance
# Processing Record 452 of Set 1 |gomel
# Processing Record 453 of Set 1 |leshukonskoye
# Processing Record 454 of Set 1 |aden
# Processing Record 455 of Set 1 |lucapa
# Processing Record 456 of Set 1 |tadine
# Processing Record 457 of Set 1 |chara
# Processing Record 458 of Set 1 |pasighat
# Processing Record 459 of Set 1 |egvekinot
# Processing Record 460 of Set 1 |hervey bay
# Processing Record 461 of Set 1 |kaliningrad
# City not found. Skipping...
# Processing Record 463 of Set 1 |padang
# Processing Record 464 of Set 1 |belmonte
# Processing Record 465 of Set 1 |sao sebastiao
# Processing Record 466 of Set 1 |tashtagol
# City not found. Skipping...
# Processing Record 468 of Set 1 |mecca
# Processing Record 469 of Set 1 |roma
# Processing Record 470 of Set 1 |phan thiet
# Processing Record 471 of Set 1 |aksarka
# Processing Record 472 of Set 1 |xalpatlahuac
# Processing Record 473 of Set 1 |svetlogorsk
# Processing Record 474 of Set 1 |gazli
# Processing Record 475 of Set 1 |tuktoyaktuk
# Processing Record 476 of Set 1 |atasu
# Processing Record 477 of Set 1 |salalah
# Processing Record 478 of Set 1 |burnie
# Processing Record 479 of Set 1 |hofu
# Processing Record 480 of Set 1 |bairiki
# Processing Record 481 of Set 1 |sorland
# Processing Record 482 of Set 1 |saldanha
# Processing Record 483 of Set 1 |nador
# Processing Record 484 of Set 1 |hofn
# City not found. Skipping...
# Processing Record 486 of Set 1 |acapulco
# Processing Record 487 of Set 1 |ankazoabo
# Processing Record 488 of Set 1 |kuytun
# Processing Record 489 of Set 1 |antalya
# Processing Record 490 of Set 1 |bathsheba
# City not found. Skipping...
# Processing Record 492 of Set 1 |san policarpo
# Processing Record 493 of Set 1 |killybegs
# Processing Record 494 of Set 1 |peace river
# Processing Record 495 of Set 1 |chicama
# Processing Record 496 of Set 1 |lata
# Processing Record 497 of Set 1 |aljezur
# Processing Record 498 of Set 1 |bandarbeyla
# Processing Record 499 of Set 1 |kuruman
# Processing Record 500 of Set 1 |ulagan
# Processing Record 501 of Set 1 |coahuayana
# Processing Record 502 of Set 1 |sisimiut
# Processing Record 503 of Set 1 |pangkalanbuun
# Processing Record 504 of Set 1 |ahuimanu
# Processing Record 505 of Set 1 |moyobamba
# Processing Record 506 of Set 1 |steamboat springs
# Processing Record 507 of Set 1 |beloha
# Processing Record 508 of Set 1 |pathardi
# Processing Record 509 of Set 1 |morehead
# Processing Record 510 of Set 1 |namibe
# Processing Record 511 of Set 1 |poya
# Processing Record 512 of Set 1 |herat
# City not found. Skipping...
# Processing Record 514 of Set 1 |ornskoldsvik
# Processing Record 515 of Set 1 |araguaina
# Processing Record 516 of Set 1 |vila franca do campo
# Processing Record 517 of Set 1 |biltine
# Processing Record 518 of Set 1 |la paz
# Processing Record 519 of Set 1 |vardo
# Processing Record 520 of Set 1 |porto novo
# Processing Record 521 of Set 1 |desbiens
# Processing Record 522 of Set 1 |kulhudhuffushi
# Processing Record 523 of Set 1 |anadyr
# Processing Record 524 of Set 1 |luganville
# Processing Record 525 of Set 1 |alofi
# Processing Record 526 of Set 1 |zholymbet
# Processing Record 527 of Set 1 |aksu
# Processing Record 528 of Set 1 |luwuk
# Processing Record 529 of Set 1 |fortuna
# Processing Record 530 of Set 1 |gannan
# City not found. Skipping...
# Processing Record 532 of Set 1 |cockburn town
# Processing Record 533 of Set 1 |abu kamal
# Processing Record 534 of Set 1 |ulladulla
# Processing Record 535 of Set 1 |bara
# Processing Record 536 of Set 1 |lockhart
# City not found. Skipping...
# Processing Record 538 of Set 1 |fuyu
# Processing Record 539 of Set 1 |lonevag
# Processing Record 540 of Set 1 |zabol
# Processing Record 541 of Set 1 |eyl
# City not found. Skipping...
# Processing Record 543 of Set 1 |limbang
# Processing Record 544 of Set 1 |tignere
# Processing Record 545 of Set 1 |shizunai
# City not found. Skipping...
# Processing Record 547 of Set 1 |grand gaube
# Processing Record 548 of Set 1 |huarmey
# Processing Record 549 of Set 1 |yingcheng
# Processing Record 550 of Set 1 |cayenne
# Processing Record 551 of Set 1 |oyama
# Processing Record 552 of Set 1 |ambilobe
# Processing Record 553 of Set 1 |seoul
# Processing Record 554 of Set 1 |ternate
# City not found. Skipping...
# Processing Record 556 of Set 1 |novikovo
# Processing Record 557 of Set 1 |humaita
# Processing Record 558 of Set 1 |nosy varika
# Processing Record 559 of Set 1 |tual
# Processing Record 560 of Set 1 |clyde river
# Processing Record 561 of Set 1 |nola
# Processing Record 562 of Set 1 |vorozhba
# Processing Record 563 of Set 1 |aksehir
# Processing Record 564 of Set 1 |maraa
# Processing Record 565 of Set 1 |dwarka
# Processing Record 566 of Set 1 |mindelo
# Processing Record 567 of Set 1 |ambon
# Processing Record 568 of Set 1 |nouadhibou
# City not found. Skipping...
# Processing Record 570 of Set 1 |front royal
# Processing Record 571 of Set 1 |loma bonita
# Processing Record 572 of Set 1 |samarai
# Processing Record 573 of Set 1 |seguela
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 576 of Set 1 |high level
# Processing Record 577 of Set 1 |lircay
# Processing Record 578 of Set 1 |honiara
# Processing Record 579 of Set 1 |cananeia
# Processing Record 580 of Set 1 |mount abu
# Processing Record 581 of Set 1 |indianola
# Processing Record 582 of Set 1 |nsawam
# Processing Record 583 of Set 1 |soyo
# Processing Record 584 of Set 1 |bereda
# Processing Record 585 of Set 1 |ranong
# Processing Record 586 of Set 1 |rokytne
# Processing Record 587 of Set 1 |kloulklubed
# Processing Record 588 of Set 1 |nizhnyaya tavda
# Processing Record 589 of Set 1 |king city
# Processing Record 590 of Set 1 |churapcha
# Processing Record 591 of Set 1 |timra
# Processing Record 592 of Set 1 |angoram
# City not found. Skipping...
# Processing Record 594 of Set 1 |usinsk
# Processing Record 595 of Set 1 |collie
# Processing Record 596 of Set 1 |port moresby
# Processing Record 597 of Set 1 |konstantinovka
# Processing Record 598 of Set 1 |cap malheureux
# Processing Record 599 of Set 1 |buchanan
# City not found. Skipping...
# Processing Record 601 of Set 1 |shemonaikha
# Processing Record 602 of Set 1 |barcelos
# Processing Record 603 of Set 1 |havoysund
# Processing Record 604 of Set 1 |presidencia roque saenz pena
# Processing Record 605 of Set 1 |miyazu
# City not found. Skipping...
# Processing Record 607 of Set 1 |biak
# Processing Record 608 of Set 1 |djibo
# Processing Record 609 of Set 1 |port macquarie
# Processing Record 610 of Set 1 |novaya igirma
# Processing Record 611 of Set 1 |never
# Processing Record 612 of Set 1 |koshurnikovo
# Processing Record 613 of Set 1 |nichinan
# Processing Record 614 of Set 1 |chumikan
# Processing Record 615 of Set 1 |atbasar
# Processing Record 616 of Set 1 |tabou
# Processing Record 617 of Set 1 |matagami
# Processing Record 618 of Set 1 |ati
# Processing Record 619 of Set 1 |jaciara
# Processing Record 620 of Set 1 |pozo colorado
# Processing Record 621 of Set 1 |tecoanapa

# %%
# create a data frame

data = {'City':name,
    'Lat' : lat,
    'Lon' : lon,
    'Max Temp' : temp_max,
    'Humidity' : humid,
    'Cloudiness' : cloud,
    'Wind Speed' : wind,
    'Country' : country,
    'Date' : date}

results = pd.DataFrame(data)
results
# Out:
#                    City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 0       Bambous Virieux -20.34   57.76     75.20        60          40
# 1          Punta Arenas -53.15  -70.92     30.20        86          88
# 2               Rikitea -23.12 -134.97     69.85        77          60
# 3                Bethel  41.37  -73.41     71.60        83          20
# 4                Harper   4.38   -7.72     75.20        69          47
# ..                  ...    ...     ...       ...       ...         ...
# 562            Matagami  49.75  -77.63     53.60        93           1
# 563                 Ati  13.22   18.34     76.33        83          98
# 564             Jaciara -15.97  -54.97     68.41        46          56
# 565       Pozo Colorado -23.49  -58.80     47.48        97           0
# 566  Barra de Tecoanapa  16.52  -98.75     79.45        78         100
#
#      Wind Speed Country        Date
# 0         16.11      MU  1597305750
# 1         10.29      CL  1597305750
# 2         16.15      PF  1597305750
# 3          4.29      US  1597305751
# 4          4.43      LR  1597305751
# ..          ...     ...         ...
# 562        1.19      CA  1597305905
# 563        8.39      TD  1597305905
# 564        3.06      BR  1597305905
# 565        4.12      PY  1597305905
# 566        2.91      MX  1597305906
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
results.count()
# Out:
# City          567
# Lat           567
# Lon           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
results_100=results['Humidity']<101
results_100.count()
# Out:
# 567

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
results.to_csv('csv/results.csv', index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = results['Lat']
y_values = results['Max Temp']
plt.scatter(x_values,y_values,edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
plt.title("City Latitude vs. Max Temp 8.9.20")
plt.grid()
plt.savefig('images/Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = results['Lat']
y_values = results['Humidity']
plt.scatter(x_values,y_values,edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity 8.9.20")
plt.grid()
plt.savefig('images/Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = results['Lat']
y_values = results['Cloudiness']
plt.scatter(x_values,y_values,edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude vs. Cloudiness 8.9.20")
plt.grid()
plt.savefig('images/Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = results['Lat']
y_values = results['Wind Speed']
plt.scatter(x_values,y_values,edgecolors='k')
plt.xlabel('Latitude')
plt.ylabel('Wind speed (%)')
plt.title("City Latitude vs. Wind Speed 8.9.20")
plt.grid()
plt.savefig('images/WindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
results_N=results[results["Lat"]>0]
results_N
# Out:
#                    City    Lat     Lon  Max Temp  Humidity  Cloudiness  \
# 3                Bethel  41.37  -73.41    295.93        90          96
# 4                Harper   4.38   -7.72    295.49        75          69
# 5            Butaritari   3.07  172.79    300.68        65          56
# 6            Port Hardy  50.70 -127.42    286.15        82          75
# 7                Tenabo  20.05  -90.23    298.92        76          91
# ..                  ...    ...     ...       ...       ...         ...
# 560             Atbasar  51.80   68.33    287.13        81         100
# 561               Tabou   4.42   -7.35    295.54        74          61
# 562            Matagami  49.75  -77.63    285.15        93           1
# 563                 Ati  13.22   18.34    297.26        85         100
# 566  Barra de Tecoanapa  16.52  -98.75    299.74        78         100
#
#      Wind Speed Country        Date
# 3          2.01      US  1597299593
# 4          2.17      LR  1597299636
# 5          1.96      KI  1597299637
# 6          2.10      CA  1597299343
# 7          1.46      MX  1597299637
# ..          ...     ...         ...
# 560        5.50      KZ  1597299793
# 561        1.67      CI  1597299794
# 562        0.86      CA  1597299794
# 563        3.61      TD  1597299794
# 566        1.30      MX  1597299795
#
# [399 rows x 9 columns]

# %%
results_S=results[results["Lat"]<0]
results_S
# Out:
#                              City    Lat     Lon  Max Temp  Humidity  \
# 0                 Bambous Virieux -20.34   57.76    297.15        57
# 1                    Punta Arenas -53.15  -70.92    273.15        90
# 2                         Rikitea -23.12 -134.97    294.34        75
# 10                         Hobart -42.88  147.33    286.48        76
# 11                         Atuona  -9.80 -139.03    299.16        73
# ..                            ...    ...     ...       ...       ...
# 550  Presidencia Roque Sáenz Peña -26.79  -60.44    283.44        56
# 552                          Biak  -0.91  122.88    302.19        62
# 554                Port Macquarie -31.43  152.92    295.93        61
# 564                       Jaciara -15.97  -54.97    294.94        43
# 565                 Pozo Colorado -23.49  -58.80    282.21        97
#
#      Cloudiness  Wind Speed Country        Date
# 0            40        5.10      MU  1597299635
# 1            38        5.70      CL  1597299626
# 2            80        8.70      PF  1597299636
# 10           75        3.10      AU  1597299399
# 11           34        6.73      PF  1597299639
# ..          ...         ...     ...         ...
# 550          94        1.21      AR  1597299790
# 552           8        3.81      ID  1597299791
# 554           1        3.05      AU  1597299590
# 564          50        1.19      BR  1597299794
# 565           0        1.86      PY  1597299795
#
# [168 rows x 9 columns]

# %%
x_values = results_N['Lat']
y_values = results_N['Max Temp']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(10,280),fontsize=15,color="red")
plt.savefig('images/North_Temp.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = results_S['Lat']
y_values = results_S['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,300),fontsize=15,color="red")

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')


plt.savefig('images/South_Temp.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = results_N['Lat']
y_values = results_N['Humidity']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.savefig('images/North_Humidity.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = results_S['Lat']
y_values = results_S['Humidity']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.savefig('images/South_Humidity.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = results_N['Lat']
y_values = results_N['Cloudiness']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,15),fontsize=15,color="red")
plt.savefig('images/North_Cloudiness.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = results_S['Lat']
y_values = results_S['Cloudiness']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.savefig('images/South_Cloudiness.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = results_N['Lat']
y_values = results_N['Wind Speed']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.savefig('images/North_WindSpeed.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = results_S['Lat']
y_values = results_S['Wind Speed']
plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.savefig('images/South_WindSpeed.png')
plt.show()

# %% [markdown]
# ### Analasys
# Results show a clear relationship to Temp and Latitude,
# but not so much to cloudiness or wind speed or even Humidity
